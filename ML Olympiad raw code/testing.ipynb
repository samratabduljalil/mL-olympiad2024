# %%
import pandas as pd
from statsmodels.tsa.arima.model import ARIMA
Train=pd.read_csv('/kaggle/input/ml-olympiad-co2-emissions-prediction-challenge/train.csv')
Test= pd.read_csv('/kaggle/input/ml-olympiad-co2-emissions-prediction-challenge/test.csv')
sample_submission= pd.read_csv('/kaggle/input/ml-olympiad-co2-emissions-prediction-challenge/sample_submission.csv')

# %%
fg = Train[Train['Country Name'] == "Bermuda"]
fg
# Out:
#     Country Code Country Name  \
# 252          Ber      Bermuda
# 253          Ber      Bermuda
# 254          Ber      Bermuda
# 255          Ber      Bermuda
# 256          Ber      Bermuda
# 257          Ber      Bermuda
# 258          Ber      Bermuda
# 259          Ber      Bermuda
# 260          Ber      Bermuda
# 261          Ber      Bermuda
# 262          Ber      Bermuda
# 263          Ber      Bermuda
#
#                                              Indicator 2000 [YR2000]  \
# 252            Access to electricity (% of population)           100
# 253                 Agricultural land (% of land area)   7.407407407
# 254  Annual freshwater withdrawals, total (% of int...            ..
# 255                       Arable land (% of land area)   7.407407407
# 256                       Forest area (% of land area)   18.51851852
# 257        Electric power consumption (kWh per capita)            ..
# 258       Energy use (kg of oil equivalent per capita)            ..
# 259  Renewable electricity output (% of total elect...             0
# 260  Renewable energy consumption (% of total final...          0.46
# 261                       Population growth (annual %)   0.890208774
# 262                       GDP per capita (current US$)   56284.16865
# 263             CO2 emissions (metric tons per capita)            ..
#
#     2001 [YR2001] 2002 [YR2002] 2003 [YR2003] 2004 [YR2004] 2005 [YR2005]  \
# 252           100           100           100           100           100
# 253   7.407407407   7.407407407   7.407407407   7.407407407   7.407407407
# 254            ..            ..            ..            ..            ..
# 255   7.407407407   7.407407407   7.407407407   7.407407407   7.407407407
# 256   18.51851852   18.51851852   18.51851852   18.51851852   18.51851852
# 257            ..            ..            ..            ..            ..
# 258            ..            ..            ..            ..            ..
# 259             0             0             0             0             0
# 260          0.54          0.51          0.51          0.52          0.49
# 261   1.079335217   0.650636983   0.654327136    0.65321131   0.647413399
# 262   58883.95943    62583.1002   66111.72523   70359.31911   75882.03386
# 263            ..            ..            ..            ..            ..
#
#     2006 [YR2006] 2007 [YR2007] 2008 [YR2008] 2009 [YR2009] 2010 [YR2010]  \
# 252           100           100           100           100           100
# 253   7.407407407   7.407407407   5.555555556   5.555555556   5.555555556
# 254            ..            ..            ..            ..            ..
# 255   7.407407407   7.407407407   5.555555556   5.555555556   5.555555556
# 256   18.51851852   18.51851852   18.51851852   18.51851852   18.51851852
# 257            ..            ..            ..            ..            ..
# 258            ..            ..            ..            ..            ..
# 259             0             0             0             0             0
# 260          0.44           0.5          0.46          0.43          0.43
# 261   0.573530641   0.564095738   0.591576775    0.55458514  -0.783118104
# 262   95221.85887   104287.3875   106935.4863    101407.764   101875.2841
# 263            ..            ..            ..            ..            ..
#
#     2011 [YR2011] 2012 [YR2012] 2013 [YR2013] 2014 [YR2014] 2015 [YR2015]
# 252           100           100           100           100           100
# 253   5.555555556   5.555555556   5.555555556   5.555555556   5.555555556
# 254            ..            ..            ..            ..            ..
# 255   5.555555556   5.555555556   5.555555556   5.555555556   5.555555556
# 256   18.51851852   18.51851852   18.51851852   18.51851852   18.51851852
# 257            ..            ..            ..            ..            ..
# 258            ..            ..            ..            ..            ..
# 259             0             0             0             0             0
# 260          0.42          0.44          1.47          0.43          0.55
# 261  -0.863616496   0.361775877   0.312791571   0.210544188   0.151869636
# 262   97774.16207   98431.86518    99471.6389   98467.68399   102005.6256
# 263            ..            ..            ..            ..            ..
