# %%
import pandas as pd
from statsmodels.tsa.arima.model import ARIMA
Train=pd.read_csv('/kaggle/input/ml-olympiad-co2-emissions-prediction-challenge/train.csv')
Test= pd.read_csv('/kaggle/input/ml-olympiad-co2-emissions-prediction-challenge/test.csv')
sample_submission= pd.read_csv('/kaggle/input/dataset-creation/3- co-emissions-per-capita.csv')
sample_submission2= pd.read_csv('/kaggle/input/ml-olympiad-co2-emissions-prediction-challenge/sample_submission.csv')

# %%
sample_submission2= pd.read_csv('/kaggle/input/subissino/submission (28) (1).csv')

# %%
Train=pd.read_csv('/kaggle/input/ml-olympiad-co2-emissions-prediction-challenge/train.csv')

# %%
Train2
# Out:
#      Country Code Country Name  \
# 0             Afg  Afghanistan
# 1             Afg  Afghanistan
# 2             Afg  Afghanistan
# 3             Afg  Afghanistan
# 4             Afg  Afghanistan
# ...           ...          ...
# 3187          Wor        World
# 3188          Wor        World
# 3189          Wor        World
# 3190          Wor        World
# 3191          Wor        World
#
#                                               Indicator 2000 [YR2000]  \
# 0               Access to electricity (% of population)   4.446890831
# 1                    Agricultural land (% of land area)   57.94581666
# 2     Annual freshwater withdrawals, total (% of int...   43.01590668
# 3                          Arable land (% of land area)   11.77958696
# 4                          Forest area (% of land area)   1.852781994
# ...                                                 ...           ...
# 3187  Renewable electricity output (% of total elect...   18.33315487
# ...

# %%
j= pd.read_csv('/kaggle/input/missing-prediction/data.csv')
missing_value2 = j.values
training_list=[]
training_list = [j for j in unique if j not in missing_value2]
unique_values = set(training_list)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 4
#       2 missing_value2 = j.values
#       3 training_list=[]
# ----> 4 training_list = [j for j in unique if j not in missing_value2]
#       5 unique_values = set(training_list)
#
# NameError: name 'unique' is not defined

# %%
sample_submission

# %%
unique_p= sample_submission['Entity'].unique()

# %%
unique_p

# %%
j= pd.read_csv('/kaggle/input/missing-prediction/data.csv')
missing_value2 = j.values
training_list=[]
training_list = [j for j in missing_value2 if j in unique_p]
unique_values = set(training_list)
unique_values
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 5
#       3 training_list=[]
#       4 training_list = [j for j in missing_value2 if j in unique_p]
# ----> 5 unique_values = set(training_list)
#       6 unique_values
#
# TypeError: unhashable type: 'numpy.ndarray'

# %%
for i in training_list:
    print(i[0])
# Out:
# Aruba
# Bermuda
# British Virgin Islands
# Curacao
# Faroe Islands
# French Polynesia
# Greenland
# Kosovo
# New Caledonia
# Sint Maarten (Dutch part)
# Turks and Caicos Islands

# %%
sample_submission

# %%
filtered_df = sample_submission[sample_submission['Year'].isin([2000, 2001, 2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015])]

# %%
filtered_df
# Out:
#             Entity Code  Year  Annual CO₂ emissions (per capita)
# 51     Afghanistan  AFG  2000                           0.053581
# 52     Afghanistan  AFG  2001                           0.054300
# 53     Afghanistan  AFG  2002                           0.063856
# 54     Afghanistan  AFG  2003                           0.068871
# 55     Afghanistan  AFG  2004                           0.052529
# ...            ...  ...   ...                                ...
# 26588     Zimbabwe  ZWE  2011                           0.795591
# 26589     Zimbabwe  ZWE  2012                           0.848359
# 26590     Zimbabwe  ZWE  2013                           0.861012
# 26591     Zimbabwe  ZWE  2014                           0.862179
# 26592     Zimbabwe  ZWE  2015                           0.865772
#
# [3692 rows x 4 columns]

# %%
for i in training_list:
    fg = Train[Train['Country Name'] == i[0]]

# %%
fg = Train[Train['Country Name'] == training_list[0][0]]
fg2 = filtered_df[filtered_df['Entity'] == training_list[0][0]]

# %%
tr=fg2['Annual CO₂ emissions (per capita)'].reset_index(drop=True)

# %%
fg2

# %%
training_list.remove('Kosovo')

# %%
training_list
# Out:
# [array(['Aruba'], dtype=object),
#  array(['Bermuda'], dtype=object),
#  array(['British Virgin Islands'], dtype=object),
#  array(['Curacao'], dtype=object),
#  array(['Faroe Islands'], dtype=object),
#  array(['French Polynesia'], dtype=object),
#  array(['Greenland'], dtype=object),
#  array(['New Caledonia'], dtype=object),
#  array(['Sint Maarten (Dutch part)'], dtype=object),
#  array(['Turks and Caicos Islands'], dtype=object)]

# %%
columns_to_drop = ['Country Code']
Train = Train.drop(columns_to_drop, axis=1)

# %%
for i in training_list:
    try:
        fg = Train2[Train2['Country Name'] == i[0]]
        fg2 = filtered_df[filtered_df['Entity'] == i[0]]
        tr=fg2['Annual CO₂ emissions (per capita)'].reset_index(drop=True)
        row_index = Train[(Train['Country Name'] == i[0]) & (Train['Indicator'] == 'CO2 emissions (metric tons per capita)')].index[0]
            
        

        new_values = [i[0],'CO2 emissions (metric tons per capita)',tr[0],tr[1],tr[2],tr[3],tr[4],tr[5],tr[6],tr[7],tr[8],tr[9],tr[10],tr[11],tr[12],tr[13],tr[14],tr[15]]
        Train.loc[row_index] = new_values
    except:
        print(i[0])

# %%
row_index
# Out:
# 24264

# %%
for i in training_list:
        fg = Train[Train['Country Name'] == i[0]]
        fg2 = filtered_df[filtered_df['Entity'] == i[0]]
        tr=fg2['Annual CO₂ emissions (per capita)'].reset_index(drop=True)
        for index, row in Train.iterrows():
            # Check if both 'sa' and 'ka' are present in the row
            if i[0] in row.values and 'ka' in row.values:
            # If both are present, get the index of the first occurrence and break the loop
                column_index = row[row.isin([i[0], 'CO2 emissions (metric tons per capita)'])].index[0]
                break

        new_values = [i,tr[0],tr[1],tr[2],tr[3],tr[4],tr[5],tr[6],tr[7],tr[8],tr[9],tr[10],tr[11],tr[12],tr[13],tr[14],tr[15]]
        Train.loc[row_index] = new_values

# %%
filtered_df
# Out:
#             Entity Code  Year  Annual CO₂ emissions (per capita)
# 51     Afghanistan  AFG  2000                           0.053581
# 52     Afghanistan  AFG  2001                           0.054300
# 53     Afghanistan  AFG  2002                           0.063856
# 54     Afghanistan  AFG  2003                           0.068871
# 55     Afghanistan  AFG  2004                           0.052529
# ...            ...  ...   ...                                ...
# 26588     Zimbabwe  ZWE  2011                           0.795591
# 26589     Zimbabwe  ZWE  2012                           0.848359
# 26590     Zimbabwe  ZWE  2013                           0.861012
# 26591     Zimbabwe  ZWE  2014                           0.862179
# 26592     Zimbabwe  ZWE  2015                           0.865772
#
# [3692 rows x 4 columns]

# %%
filtered_df2 = filtered_df[filtered_df['Entity'].isin(['Aruba',
'Bermuda',
'British Virgin Islands',
'Curacao',
'Faroe Islands',
'French Polynesia',
'Greenland',
'Kosovo',
'New Caledonia',
'Sint Maarten (Dutch part)',
'Turks and Caicos Islands'])]

# %%
filtered_df2
# Out:
#                          Entity Code  Year  Annual CO₂ emissions (per capita)
# 1258                      Aruba  ABW  2000                          26.683304
# 1259                      Aruba  ABW  2001                          26.540186
# 1260                      Aruba  ABW  2002                          26.542625
# 1261                      Aruba  ABW  2003                          27.624346
# 1262                      Aruba  ABW  2004                          27.963486
# ...                         ...  ...   ...                                ...
# 24285  Turks and Caicos Islands  TCA  2011                           9.148119
# 24286  Turks and Caicos Islands  TCA  2012                           8.787665
# 24287  Turks and Caicos Islands  TCA  2013                           8.500654
# 24288  Turks and Caicos Islands  TCA  2014                           8.790084
# 24289  Turks and Caicos Islands  TCA  2015                           8.519531
#
# [172 rows x 4 columns]

# %%
f1=filtered_df[filtered_df['Entity'].isin(['Aruba'])]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 f1=filtered_df[filtered_df['Entity'].isin(['Aruba'])]
#
# NameError: name 'filtered_df' is not defined

# %%
for i in training_list:
    f1=filtered_df[filtered_df['Entity'].isin([i[0]])]
    print(f1)
    print('eatting')
# Out:
#      Entity Code  Year  Annual CO₂ emissions (per capita)
# 1258  Aruba  ABW  2000                          26.683304
# 1259  Aruba  ABW  2001                          26.540186
# 1260  Aruba  ABW  2002                          26.542625
# 1261  Aruba  ABW  2003                          27.624346
# 1262  Aruba  ABW  2004                          27.963486
# 1263  Aruba  ABW  2005                          28.770708
# 1264  Aruba  ABW  2006                          28.393595
# 1265  Aruba  ABW  2007                          29.146358
# 1266  Aruba  ABW  2008                          27.104464
# 1267  Aruba  ABW  2009                          26.476603
# 1268  Aruba  ABW  2010                          24.973354
# 1269  Aruba  ABW  2011                          24.666824
# 1270  Aruba  ABW  2012                          13.202827
# 1271  Aruba  ABW  2013                           8.368467
# 1272  Aruba  ABW  2014                           8.416729
# ...

# %%
fg = Train[Train['Country Name'] == 'Sint Maarten (Dutch part)']
fg
# Out:
#                    Country Name  \
# 2064  Sint Maarten (Dutch part)
# 2065  Sint Maarten (Dutch part)
# 2066  Sint Maarten (Dutch part)
# 2067  Sint Maarten (Dutch part)
# 2068  Sint Maarten (Dutch part)
# 2069  Sint Maarten (Dutch part)
# 2070  Sint Maarten (Dutch part)
# 2071  Sint Maarten (Dutch part)
# 2072  Sint Maarten (Dutch part)
# 2073  Sint Maarten (Dutch part)
# 2074  Sint Maarten (Dutch part)
# 2075  Sint Maarten (Dutch part)
#
#                                               Indicator 2000 [YR2000]  \
# 2064            Access to electricity (% of population)    99.9613266
# 2065                 Agricultural land (% of land area)         0.102
# 2066  Annual freshwater withdrawals, total (% of int...         0.102
# 2067                       Arable land (% of land area)         0.102
# 2068                       Forest area (% of land area)         0.102
# 2069        Electric power consumption (kWh per capita)         0.102
# ...

# %%
Train.to_csv('newtrain.csv', index=False)

# %%
#replace ".."with .100
Train=Train.replace('..', .102)  
Test=Test.replace('..', 0.102)

# %%
#trainig and inferencing with LogisticRegression and ARIMA
import pandas as pd
import warnings
warnings.filterwarnings("ignore")
from statsmodels.tsa.arima.model import ARIMA
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsRegressor
import numpy as np
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
j=[]
for i in training_list:
    transposed_df=0
    fg = Train[Train['Country Name'] == i[0]].reset_index(drop=True)
    columns_to_drop = ['Country Name','Indicator']
    fg = fg.drop(columns_to_drop, axis=1)
    transposed_df = fg.transpose()
    #print(fg)
    #print('done for now')
    Xtrain = transposed_df[[0,1, 2,3,4,9,10]]
    Xtrain
    Ytrain=transposed_df[11]
    Ytrain
    logistic_regression = LogisticRegression()
    try:
        logistic_regression.fit(Xtrain,Ytrain)
        fgt = Test[Test['Country Name'] == i[0]].reset_index(drop=True)
        columns_to_drop = [ 'Country Name','Indicator']
        fgt = fgt.drop(columns_to_drop, axis=1)
        transposed_df = fgt.transpose()
        #print(transposed_df)
  
        Xtest = transposed_df[[0,1, 2,3,4,9,10]]
        forecast = logistic_regression.predict(Xtest.astype(float))
        
        model2 = ARIMA(Ytrain.astype(float), order=(0,1,0))  # Adjust order as needed
        model_fit2 = model2.fit()

    
        forecast2 = model_fit2.forecast(steps=16)
        
        row_index = sample_submission2[sample_submission2.eq(i[0]).any(axis=1)].index[0]


        new_values = [i[0], forecast[0], forecast[1],forecast[2], forecast[3], forecast[4],forecast2[30]]
        sample_submission2.loc[row_index] = new_values
    except:
        j.append(i[0])
print(j)
# Out:
# ['Aruba', 'Bermuda', 'British Virgin Islands', 'Curacao', 'Faroe Islands', 'French Polynesia', 'Greenland', 'New Caledonia', 'Sint Maarten (Dutch part)', 'Turks and Caicos Islands']

# %%
#trainig and inferencing with LogisticRegression and ARIMA
import pandas as pd
import warnings
warnings.filterwarnings("ignore")
from statsmodels.tsa.arima.model import ARIMA
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsRegressor
import numpy as np
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
j=[]
for i in training_list:
    transposed_df=0
    fg = Train[Train['Country Name'] == i[0]].reset_index(drop=True)
    columns_to_drop = ['Country Name','Indicator']
    fg = fg.drop(columns_to_drop, axis=1)
    transposed_df = fg.transpose()
    #print(fg)
    #print('done for now')
    Xtrain = transposed_df[[0,1, 2,3,4,9,10]]
    Xtrain
    Ytrain=transposed_df[11]
    Ytrain
    logistic_regression = KNeighborsRegressor()
    #print(Ytrain)
    logistic_regression.fit(Xtrain.astype(float),Ytrain.astype(float))
    fgt = Test[Test['Country Name'] == i[0]].reset_index(drop=True)
    columns_to_drop = [ 'Country Name','Indicator']
    fgt = fgt.drop(columns_to_drop, axis=1)
    transposed_df = fgt.transpose()
        #print(transposed_df)
  
    Xtest = transposed_df[[0,1, 2,3,4,9,10]]
    forecast = logistic_regression.predict(Xtest.astype(float))
        
    model2 = ARIMA(Ytrain.astype(float), order=(0,1,0))  # Adjust order as needed
    model_fit2 = model2.fit()

    
    forecast2 = model_fit2.forecast(steps=16)
        
    row_index = sample_submission2[sample_submission2.eq(i[0]).any(axis=1)].index[0]


    new_values = [i[0], forecast2[16], forecast2[17],forecast2[18], forecast2[19], forecast2[20],forecast2[30]]
    sample_submission2.loc[row_index] = new_values
  
    j.append(i[0])
print(j)
# Out:
# ['Aruba', 'Bermuda', 'British Virgin Islands', 'Curacao', 'Faroe Islands', 'French Polynesia', 'Greenland', 'New Caledonia', 'Sint Maarten (Dutch part)', 'Turks and Caicos Islands']

# %%
fg = sample_submission2[sample_submission2['Country Name'] == 'Aruba']
fg
# Out:
#   Country Name 2016 [YR2016] 2017 [YR2017] 2018 [YR2018] 2019 [YR2019]  \
# 9        Aruba       8.60927       8.60927       8.60927       8.60927
#
#   2020 [YR2020]  2030 [YR2030]
# 9       8.60927        8.60927

# %%
sample_submission2.to_csv('submission.csv', index=False)
