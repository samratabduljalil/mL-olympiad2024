# %%
import pandas as pd
from statsmodels.tsa.arima.model import ARIMA
Train=pd.read_csv('/kaggle/input/ml-olympiad-co2-emissions-prediction-challenge/train.csv')
Test= pd.read_csv('/kaggle/input/ml-olympiad-co2-emissions-prediction-challenge/test.csv')
sample_submission= pd.read_csv('/kaggle/input/ml-olympiad-co2-emissions-prediction-challenge/sample_submission.csv')

# %%
#Filter BY CO2 emissions (metric tons per capita)
specific_string = 'CO2 emissions (metric tons per capita)'
filtered_rows = Train[Train['Indicator'] == specific_string]
filtered_rows
# Out:
#      Country Code                                Country Name  \
# 11            Afg                                 Afghanistan
# 23            Alb                                     Albania
# 35            Alg                                     Algeria
# 47            Ame                              American Samoa
# 59            And                                     Andorra
# ...           ...                                         ...
# 3143          Sub                          Sub-Saharan Africa
# 3155          Sub  Sub-Saharan Africa (excluding high income)
# 3167          Sub   Sub-Saharan Africa (IDA & IBRD countries)
# 3179          Upp                         Upper middle income
# 3191          Wor                                       World
#
#                                    Indicator 2000 [YR2000] 2001 [YR2001]  \
# 11    CO2 emissions (metric tons per capita)   0.055166607   0.055292719
# 23    CO2 emissions (metric tons per capita)   1.031567545   1.056868354
# 35    CO2 emissions (metric tons per capita)   2.601065339   2.520609526
# 47    CO2 emissions (metric tons per capita)            ..            ..
# 59    CO2 emissions (metric tons per capita)   7.927016355   7.725626659
# ...                                      ...           ...           ...
# 3143  CO2 emissions (metric tons per capita)   0.742866043   0.787827764
# 3155  CO2 emissions (metric tons per capita)   0.742518227   0.787450847
# 3167  CO2 emissions (metric tons per capita)   0.742866043   0.787827764
# 3179  CO2 emissions (metric tons per capita)   3.167140886   3.243556127
# 3191  CO2 emissions (metric tons per capita)   3.951660425   3.958088692
#
#      2002 [YR2002] 2003 [YR2003] 2004 [YR2004] 2005 [YR2005] 2006 [YR2006]  \
# 11     0.066810138   0.073004968   0.054866759   0.080361134   0.089756909
# 23     1.233001531   1.361158778   1.427944204   1.360092207   1.363988602
# 35     2.605694613   2.751098761   2.752758782    2.85792657   2.985149131
# 47              ..            ..            ..            ..            ..
# 59     7.498764979   7.238069466   7.286756008   7.206273645   6.805400082
# ...            ...           ...           ...           ...           ...
# 3143   0.770312004   0.793663742   0.816417132   0.799086697   0.776663194
# 3155   0.769905273   0.793282981   0.815993983   0.798675052   0.776252936
# 3167   0.770312004   0.793663742   0.816417132   0.799086697   0.776663194
# 3179   3.347641763   3.646680369   3.955406019   4.246087066   4.524939703
# 3191   3.961470273   4.090081614   4.223794234   4.329790027   4.417134594
#
#      2007 [YR2007] 2008 [YR2008] 2009 [YR2009] 2010 [YR2010] 2011 [YR2011]  \
# 11     0.109940042   0.165573355   0.239506901   0.304230216   0.408965291
# 23     1.433796507   1.428249586   1.492116704    1.64276193   1.768108509
# 35     3.023502915   3.116770947   3.187069044      3.184357   3.305232517
# 47              ..            ..            ..            ..            ..
# 59     6.890389929   7.081822365   6.995396198   7.223590934   6.957586407
# ...            ...           ...           ...           ...           ...
# 3143   0.776076215    0.80414679   0.755561429   0.786758499   0.763961095
# 3155    0.77565827    0.80372919   0.755114664   0.786334412   0.763583523
# 3167   0.776076215    0.80414679   0.755561429   0.786758499   0.763961095
# 3179   4.770829501    4.86797795   4.944131035   5.315663058   5.673918008
# 3191   4.528275107   4.503795413   4.391450538   4.604869382    4.68946885
#
#      2012 [YR2012] 2013 [YR2013] 2014 [YR2014] 2015 [YR2015]
# 11     0.335061035   0.298087813   0.283692396   0.297971775
# 23     1.565921402   1.656389503   1.795712442   1.665218525
# 35     3.621367718   3.658468679   3.811521147   3.951960939
# 47              ..            ..            ..            ..
# 59      6.86229282   6.674233189   6.445930663   6.485769241
# ...            ...           ...           ...           ...
# 3143   0.771660846   0.790531658   0.802872437    0.76398389
# 3155   0.771278211   0.790174495   0.802481827   0.763559116
# 3167   0.771660846   0.790531658   0.802872437    0.76398389
# 3179   5.764481643   5.885587659   5.857718499   5.735859454
# 3191   4.685377082   4.719665779   4.682408225   4.601683731
#
# [266 rows x 19 columns]

# %%
#Drop Indicator Column
filtered_rows.drop(columns=['Indicator'], inplace=True)
filtered_rows
# Out:
# /tmp/ipykernel_18/1368651258.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_rows.drop(columns=['Indicator'], inplace=True)
#      Country Code                                Country Name 2000 [YR2000]  \
# 11            Afg                                 Afghanistan   0.055166607
# 23            Alb                                     Albania   1.031567545
# 35            Alg                                     Algeria   2.601065339
# 47            Ame                              American Samoa            ..
# 59            And                                     Andorra   7.927016355
# ...           ...                                         ...           ...
# 3143          Sub                          Sub-Saharan Africa   0.742866043
# 3155          Sub  Sub-Saharan Africa (excluding high income)   0.742518227
# 3167          Sub   Sub-Saharan Africa (IDA & IBRD countries)   0.742866043
# 3179          Upp                         Upper middle income   3.167140886
# 3191          Wor                                       World   3.951660425
#
#      2001 [YR2001] 2002 [YR2002] 2003 [YR2003] 2004 [YR2004] 2005 [YR2005]  \
# 11     0.055292719   0.066810138   0.073004968   0.054866759   0.080361134
# 23     1.056868354   1.233001531   1.361158778   1.427944204   1.360092207
# 35     2.520609526   2.605694613   2.751098761   2.752758782    2.85792657
# 47              ..            ..            ..            ..            ..
# 59     7.725626659   7.498764979   7.238069466   7.286756008   7.206273645
# ...            ...           ...           ...           ...           ...
# 3143   0.787827764   0.770312004   0.793663742   0.816417132   0.799086697
# 3155   0.787450847   0.769905273   0.793282981   0.815993983   0.798675052
# 3167   0.787827764   0.770312004   0.793663742   0.816417132   0.799086697
# 3179   3.243556127   3.347641763   3.646680369   3.955406019   4.246087066
# 3191   3.958088692   3.961470273   4.090081614   4.223794234   4.329790027
#
#      2006 [YR2006] 2007 [YR2007] 2008 [YR2008] 2009 [YR2009] 2010 [YR2010]  \
# 11     0.089756909   0.109940042   0.165573355   0.239506901   0.304230216
# 23     1.363988602   1.433796507   1.428249586   1.492116704    1.64276193
# 35     2.985149131   3.023502915   3.116770947   3.187069044      3.184357
# 47              ..            ..            ..            ..            ..
# 59     6.805400082   6.890389929   7.081822365   6.995396198   7.223590934
# ...            ...           ...           ...           ...           ...
# 3143   0.776663194   0.776076215    0.80414679   0.755561429   0.786758499
# 3155   0.776252936    0.77565827    0.80372919   0.755114664   0.786334412
# 3167   0.776663194   0.776076215    0.80414679   0.755561429   0.786758499
# 3179   4.524939703   4.770829501    4.86797795   4.944131035   5.315663058
# 3191   4.417134594   4.528275107   4.503795413   4.391450538   4.604869382
#
#      2011 [YR2011] 2012 [YR2012] 2013 [YR2013] 2014 [YR2014] 2015 [YR2015]
# 11     0.408965291   0.335061035   0.298087813   0.283692396   0.297971775
# 23     1.768108509   1.565921402   1.656389503   1.795712442   1.665218525
# 35     3.305232517   3.621367718   3.658468679   3.811521147   3.951960939
# 47              ..            ..            ..            ..            ..
# 59     6.957586407    6.86229282   6.674233189   6.445930663   6.485769241
# ...            ...           ...           ...           ...           ...
# 3143   0.763961095   0.771660846   0.790531658   0.802872437    0.76398389
# 3155   0.763583523   0.771278211   0.790174495   0.802481827   0.763559116
# 3167   0.763961095   0.771660846   0.790531658   0.802872437    0.76398389
# 3179   5.673918008   5.764481643   5.885587659   5.857718499   5.735859454
# 3191    4.68946885   4.685377082   4.719665779   4.682408225   4.601683731
#
# [266 rows x 18 columns]

# %%
#Drop Country Code Column
filtered_rows.drop(columns=['Country Code'], inplace=True)
filtered_rows
# Out:
# /tmp/ipykernel_18/3319185666.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_rows.drop(columns=['Country Code'], inplace=True)
#                                     Country Name 2000 [YR2000] 2001 [YR2001]  \
# 11                                   Afghanistan   0.055166607   0.055292719
# 23                                       Albania   1.031567545   1.056868354
# 35                                       Algeria   2.601065339   2.520609526
# 47                                American Samoa            ..            ..
# 59                                       Andorra   7.927016355   7.725626659
# ...                                          ...           ...           ...
# 3143                          Sub-Saharan Africa   0.742866043   0.787827764
# 3155  Sub-Saharan Africa (excluding high income)   0.742518227   0.787450847
# 3167   Sub-Saharan Africa (IDA & IBRD countries)   0.742866043   0.787827764
# 3179                         Upper middle income   3.167140886   3.243556127
# 3191                                       World   3.951660425   3.958088692
#
#      2002 [YR2002] 2003 [YR2003] 2004 [YR2004] 2005 [YR2005] 2006 [YR2006]  \
# 11     0.066810138   0.073004968   0.054866759   0.080361134   0.089756909
# 23     1.233001531   1.361158778   1.427944204   1.360092207   1.363988602
# 35     2.605694613   2.751098761   2.752758782    2.85792657   2.985149131
# 47              ..            ..            ..            ..            ..
# 59     7.498764979   7.238069466   7.286756008   7.206273645   6.805400082
# ...            ...           ...           ...           ...           ...
# 3143   0.770312004   0.793663742   0.816417132   0.799086697   0.776663194
# 3155   0.769905273   0.793282981   0.815993983   0.798675052   0.776252936
# 3167   0.770312004   0.793663742   0.816417132   0.799086697   0.776663194
# 3179   3.347641763   3.646680369   3.955406019   4.246087066   4.524939703
# 3191   3.961470273   4.090081614   4.223794234   4.329790027   4.417134594
#
#      2007 [YR2007] 2008 [YR2008] 2009 [YR2009] 2010 [YR2010] 2011 [YR2011]  \
# 11     0.109940042   0.165573355   0.239506901   0.304230216   0.408965291
# 23     1.433796507   1.428249586   1.492116704    1.64276193   1.768108509
# 35     3.023502915   3.116770947   3.187069044      3.184357   3.305232517
# 47              ..            ..            ..            ..            ..
# 59     6.890389929   7.081822365   6.995396198   7.223590934   6.957586407
# ...            ...           ...           ...           ...           ...
# 3143   0.776076215    0.80414679   0.755561429   0.786758499   0.763961095
# 3155    0.77565827    0.80372919   0.755114664   0.786334412   0.763583523
# 3167   0.776076215    0.80414679   0.755561429   0.786758499   0.763961095
# 3179   4.770829501    4.86797795   4.944131035   5.315663058   5.673918008
# 3191   4.528275107   4.503795413   4.391450538   4.604869382    4.68946885
#
#      2012 [YR2012] 2013 [YR2013] 2014 [YR2014] 2015 [YR2015]
# 11     0.335061035   0.298087813   0.283692396   0.297971775
# 23     1.565921402   1.656389503   1.795712442   1.665218525
# 35     3.621367718   3.658468679   3.811521147   3.951960939
# 47              ..            ..            ..            ..
# 59      6.86229282   6.674233189   6.445930663   6.485769241
# ...            ...           ...           ...           ...
# 3143   0.771660846   0.790531658   0.802872437    0.76398389
# 3155   0.771278211   0.790174495   0.802481827   0.763559116
# 3167   0.771660846   0.790531658   0.802872437    0.76398389
# 3179   5.764481643   5.885587659   5.857718499   5.735859454
# 3191   4.685377082   4.719665779   4.682408225   4.601683731
#
# [266 rows x 17 columns]

# %%
#Covert Year Column in rows
melted_df = filtered_rows.melt(id_vars='Country Name', var_name='Year', value_name='CO2_Emissions')
melted_df
# Out:
#                                     Country Name           Year CO2_Emissions
# 0                                    Afghanistan  2000 [YR2000]   0.055166607
# 1                                        Albania  2000 [YR2000]   1.031567545
# 2                                        Algeria  2000 [YR2000]   2.601065339
# 3                                 American Samoa  2000 [YR2000]            ..
# 4                                        Andorra  2000 [YR2000]   7.927016355
# ...                                          ...            ...           ...
# 4251                          Sub-Saharan Africa  2015 [YR2015]    0.76398389
# 4252  Sub-Saharan Africa (excluding high income)  2015 [YR2015]   0.763559116
# 4253   Sub-Saharan Africa (IDA & IBRD countries)  2015 [YR2015]    0.76398389
# 4254                         Upper middle income  2015 [YR2015]   5.735859454
# 4255                                       World  2015 [YR2015]   4.601683731
#
# [4256 rows x 3 columns]

# %%
#Sort Row in accending order by Year and Country Name
sorted_df = melted_df.groupby('Country Name').apply(lambda x: x.sort_values('Year')).reset_index(drop=True)
sorted_df.head(20)
# Out:
# /tmp/ipykernel_18/1831615012.py:2: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   sorted_df = melted_df.groupby('Country Name').apply(lambda x: x.sort_values('Year')).reset_index(drop=True)
#                    Country Name           Year CO2_Emissions
# 0                   Afghanistan  2000 [YR2000]   0.055166607
# 1                   Afghanistan  2001 [YR2001]   0.055292719
# 2                   Afghanistan  2002 [YR2002]   0.066810138
# 3                   Afghanistan  2003 [YR2003]   0.073004968
# 4                   Afghanistan  2004 [YR2004]   0.054866759
# 5                   Afghanistan  2005 [YR2005]   0.080361134
# 6                   Afghanistan  2006 [YR2006]   0.089756909
# 7                   Afghanistan  2007 [YR2007]   0.109940042
# 8                   Afghanistan  2008 [YR2008]   0.165573355
# 9                   Afghanistan  2009 [YR2009]   0.239506901
# 10                  Afghanistan  2010 [YR2010]   0.304230216
# 11                  Afghanistan  2011 [YR2011]   0.408965291
# 12                  Afghanistan  2012 [YR2012]   0.335061035
# 13                  Afghanistan  2013 [YR2013]   0.298087813
# 14                  Afghanistan  2014 [YR2014]   0.283692396
# 15                  Afghanistan  2015 [YR2015]   0.297971775
# 16  Africa Eastern and Southern  2000 [YR2000]   0.891352058
# 17  Africa Eastern and Southern  2001 [YR2001]   0.958882806
# 18  Africa Eastern and Southern  2002 [YR2002]   0.961553407
# 19  Africa Eastern and Southern  2003 [YR2003]   0.988082951

# %%
#All country name into unique_values
unique_values = melted_df['Country Name'].unique()
unique_values.shape
# Out:
# (266,)

# %%
new_value = 0.00
sorted_df = sorted_df.replace('..', new_value)

# %%
import numpy as np
import pandas as pd
from statsmodels.tsa.statespace.sarimax import SARIMAX
from sklearn.metrics import mean_squared_error
import warnings

# Ignore all warnings
warnings.filterwarnings("ignore")
warnings.resetwarnings()
total=0
j=0
for i in unique_values:
    afg = sorted_df[sorted_df['Country Name'] == i]
    # Define SARIMAX parameters
    order = (1, 1, 0)  # (p, d, q)
    seasonal_order = (1, 1, 0, 6)  # (P, D, Q, s)
    # Fit SARIMAX model
    model = SARIMAX(afg['CO2_Emissions'].astype(float), order=order, seasonal_order=seasonal_order)
    result = model.fit()

    # Predictions
    forecast_steps = 16  # Number of steps to forecast
    forecast = result.forecast(steps=forecast_steps)
    row_index = sample_submission[sample_submission.eq(i).any(axis=1)].index[0]


    new_values = [i, forecast[16], forecast[17],forecast[18], forecast[19], forecast[20],forecast[30]]
    sample_submission.loc[row_index] = new_values
# Out:
# /opt/conda/lib/python3.10/site-packages/statsmodels/tsa/statespace/sarimax.py:997: UserWarning: Non-stationary starting seasonal autoregressive Using zeros as starting parameters.
#   warn('Non-stationary starting seasonal autoregressive'
#  This problem is unconstrained.
#
#  Warning:  more than 10 function and gradient
#    evaluations in the last line search.  Termination
#    may possibly be caused by a bad search direction.
# /opt/conda/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
#  This problem is unconstrained.
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -8.47049D-01    |proj g|=  1.05029D+00
#
# At iterate    5    f= -8.50732D-01    |proj g|=  1.68780D-01
#
# At iterate   10    f= -9.12263D-01    |proj g|=  2.54783D-01
#
# At iterate   15    f= -9.25596D-01    |proj g|=  1.13664D+00
#
# At iterate   20    f= -9.71111D-01    |proj g|=  2.94077D-01
#
# At iterate   25    f= -9.72204D-01    |proj g|=  4.62155D-03
#   ys=-1.387E-05  -gs= 1.230E-05 BFGS update SKIPPED
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3     27     59      1     1     0   1.237D-02  -9.722D-01
#   F = -0.97220432079316810
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -3.18166D-01    |proj g|=  6.60272D-01
#
# At iterate    5    f= -3.24429D-01    |proj g|=  1.67679D-01
#
# At iterate   10    f= -3.25084D-01    |proj g|=  8.79498D-02
#
# At iterate   15    f= -3.25344D-01    |proj g|=  3.49832D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3     17     29      1     0     0   3.466D-04  -3.253D-01
#   F = -0.32534391590385309
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -6.06588D-01    |proj g|=  3.72052D-01
#
# At iterate    5    f= -6.07188D-01    |proj g|=  1.98108D-01
#
# At iterate   10    f= -6.15139D-01    |proj g|=  1.93732D-01
#
# At iterate   15    f= -6.17385D-01    |proj g|=  4.08252D-02
#
# At iterate   20    f= -6.18048D-01    |proj g|=  8.43224D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3     22     36      1     0     0   1.780D-03  -6.180D-01
#   F = -0.61804855208931742
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -6.46732D+00    |proj g|=  8.10841D+04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3      1     21      1     0     0   8.108D+04  -6.467D+00
#   F =  -6.4673237511833221
#
# ABNORMAL_TERMINATION_IN_LNSRCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  9.07485D-02    |proj g|=  1.32344D+00
#
# At iterate    5    f= -2.39183D-02    |proj g|=  6.33117D-02
# /opt/conda/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:836: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# /opt/conda/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:836: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(
# /opt/conda/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
#  This problem is unconstrained.
# /opt/conda/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:836: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# /opt/conda/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:836: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(
# /opt/conda/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
#  This problem is unconstrained.
#
#  Line search cannot locate an adequate point after MAXLS
#   function and gradient evaluations.
#   Previous x, f and g restored.
#  Possible causes: 1 error in function or gradient evaluation;
#                   2 rounding error dominate computation.
# /opt/conda/lib/python3.10/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /opt/conda/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:836: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# /opt/conda/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:836: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(
# /opt/conda/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
#  This problem is unconstrained.
# At iterate   10    f= -2.86945D-02    |proj g|=  8.62698D-04
#
# At iterate   15    f= -2.86984D-02    |proj g|=  1.37060D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3     18     27      1     0     0   5.802D-05  -2.870D-02
#   F =  -2.8698389923090824E-002
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -6.92176D-01    |proj g|=  6.63267D-01
#
# At iterate    5    f= -6.93306D-01    |proj g|=  2.60533D-02
#
# At iterate   10    f= -6.93354D-01    |proj g|=  5.31619D-03
#
# At iterate   15    f= -6.93373D-01    |proj g|=  5.50939D-02
#
# At iterate   20    f= -6.93388D-01    |proj g|=  1.78489D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3     22     50      1     0     0   4.203D-04  -6.934D-01
#   F = -0.69338773100695428
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -3.78654D-01    |proj g|=  1.79263D+00
#
# At iterate    5    f= -4.10104D-01    |proj g|=  9.09356D-02
#
# At iterate   10    f= -4.19588D-01    |proj g|=  2.74885D-02
#
# At iterate   15    f= -4.22543D-01    |proj g|=  4.54037D-01
#
# At iterate   20    f= -4.41221D-01    |proj g|=  1.59741D+00
# /opt/conda/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:836: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# /opt/conda/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:836: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(
# /opt/conda/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
#  This problem is unconstrained.
#
#  Warning:  more than 10 function and gradient
#    evaluations in the last line search.  Termination
#    may possibly be caused by a bad search direction.
# /opt/conda/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:836: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# /opt/conda/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:836: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(
# /opt/conda/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
#  This problem is unconstrained.
# At iterate   25    f= -4.44828D-01    |proj g|=  1.69049D-01
#
# At iterate   30    f= -4.44886D-01    |proj g|=  9.99148D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3     31     76      2     0     0   9.991D-04  -4.449D-01
#   F = -0.44488619189417200
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  4.73893D-02    |proj g|=  8.14811D-01
#
# At iterate    5    f=  1.19912D-02    |proj g|=  1.80512D-01
#
# At iterate   10    f= -7.39651D-04    |proj g|=  5.74648D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3     14     20      1     0     0   6.524D-05  -7.430D-04
#   F =  -7.4295226401916575E-004
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  5.88760D-02    |proj g|=  1.29848D+00
#
# At iterate    5    f= -6.73636D-02    |proj g|=  7.35486D-02
#
# At iterate   10    f= -1.08414D-01    |proj g|=  1.94688D-01
#
# At iterate   15    f= -1.13407D-01    |proj g|=  3.82738D-01
#
# At iterate   20    f= -1.22318D-01    |proj g|=  2.87379D+00
#  Bad direction in the line search;
#    refresh the lbfgs memory and restart the iteration.
#
#  Warning:  more than 10 function and gradient
#    evaluations in the last line search.  Termination
#    may possibly be caused by a bad search direction.
# /opt/conda/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:836: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# /opt/conda/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:836: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(
# /opt/conda/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
#  This problem is unconstrained.
# /opt/conda/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:836: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# /opt/conda/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:836: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(
# /opt/conda/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
#  This problem is unconstrained.
#
#  Warning:  more than 10 function and gradient
#    evaluations in the last line search.  Termination
#    may possibly be caused by a bad search direction.
# /opt/conda/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:836: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# /opt/conda/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:836: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(
# At iterate   25    f= -1.44489D-01    |proj g|=  9.52808D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3     25     49      1     0     0   9.528D-03  -1.445D-01
#   F = -0.14448921907702444
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -6.46732D+00    |proj g|=  8.10841D+04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3      1     21      1     0     0   8.108D+04  -6.467D+00
#   F =  -6.4673237511833221
#
# ABNORMAL_TERMINATION_IN_LNSRCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  3.39196D-01    |proj g|=  4.88128D-01
#
# At iterate    5    f=  3.01460D-01    |proj g|=  2.69523D-01
#
# At iterate   10    f=  2.67969D-01    |proj g|=  2.60475D-02
#
# At iterate   15    f=  2.67496D-01    |proj g|=  2.66478D-05
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3     17     27      1     0     0   2.537D-05   2.675D-01
#   F =  0.26749642855938066
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  5.12324D-01    |proj g|=  2.51945D-01
#
# At iterate    5    f=  4.92755D-01    |proj g|=  2.79555D-02
#
# At iterate   10    f=  4.91193D-01    |proj g|=  2.02960D-05
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3     10     13      1     0     0   2.030D-05   4.912D-01
#   F =  0.49119327787873629
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  2.55060D-01    |proj g|=  7.68439D-01
#
# At iterate    5    f=  1.63631D-01    |proj g|=  4.26196D-02
# /opt/conda/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
#  This problem is unconstrained.
# /opt/conda/lib/python3.10/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
#
#  Line search cannot locate an adequate point after MAXLS
#   function and gradient evaluations.
#   Previous x, f and g restored.
#  Possible causes: 1 error in function or gradient evaluation;
#                   2 rounding error dominate computation.
# /opt/conda/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:836: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# /opt/conda/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:836: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(
# /opt/conda/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
#  This problem is unconstrained.
# /opt/conda/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:836: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# /opt/conda/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:836: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(
# /opt/conda/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
#  This problem is unconstrained.
# /opt/conda/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:836: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# /opt/conda/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:836: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(
# /opt/conda/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
#  This problem is unconstrained.
# At iterate   10    f=  1.60878D-01    |proj g|=  4.79811D-05
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3     11     23      1     0     0   4.539D-05   1.609D-01
#   F =  0.16087803746701079
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  5.40441D-01    |proj g|=  7.46281D-02
#
# At iterate    5    f=  5.29415D-01    |proj g|=  9.94408D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3      9     13      1     0     0   1.261D-05   5.294D-01
#   F =  0.52941347654821391
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  9.03140D-01    |proj g|=  3.64625D-01
#
# At iterate    5    f=  7.41460D-01    |proj g|=  1.60759D-02
#
# At iterate   10    f=  7.40747D-01    |proj g|=  1.26069D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3     13     56      2     0     0   1.375D-05   7.407D-01
#   F =  0.74074548407252006
#
# ABNORMAL_TERMINATION_IN_LNSRCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -1.56361D+00    |proj g|=  6.91035D+00
#
# At iterate    5    f= -1.56725D+00    |proj g|=  1.27268D-01
# /opt/conda/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:836: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# /opt/conda/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:836: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(
# /opt/conda/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /opt/conda/lib/python3.10/site-packages/statsmodels/tsa/statespace/sarimax.py:997: UserWarning: Non-stationary starting seasonal autoregressive Using zeros as starting parameters.
#   warn('Non-stationary starting seasonal autoregressive'
#  This problem is unconstrained.
# /opt/conda/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:836: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# /opt/conda/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:836: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(
# /opt/conda/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
#  This problem is unconstrained.
#
#  Bad direction in the line search;
#    refresh the lbfgs memory and restart the iteration.
# /opt/conda/lib/python3.10/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
#
#  Line search cannot locate an adequate point after MAXLS
#   function and gradient evaluations.
#   Previous x, f and g restored.
#  Possible causes: 1 error in function or gradient evaluation;
#                   2 rounding error dominate computation.
# /opt/conda/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:836: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# /opt/conda/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:836: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(
# /opt/conda/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
#  This problem is unconstrained.
# At iterate   10    f= -1.56922D+00    |proj g|=  4.09286D+00
#
# At iterate   15    f= -1.57093D+00    |proj g|=  8.22350D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3     17     66      2     0     0   6.772D-03  -1.571D+00
#   F =  -1.5709343937671820
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  5.39555D-01    |proj g|=  2.01665D-01
#
# At iterate    5    f=  3.66598D-01    |proj g|=  1.54559D-01
#
# At iterate   10    f=  3.65437D-01    |proj g|=  8.62783D-05
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3     11     15      1     0     0   2.805D-05   3.654D-01
#   F =  0.36543725090341694
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  5.32211D-02    |proj g|=  2.34528D-01
#
# At iterate    5    f=  4.95700D-02    |proj g|=  1.27172D-02
#
# At iterate   10    f=  4.94217D-02    |proj g|=  1.81650D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3     11     16      1     0     0   1.487D-04   4.942D-02
#   F =   4.9421686696725739E-002
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  4.37892D-01    |proj g|=  1.16496D+00
#
# At iterate    5    f=  1.56142D-01    |proj g|=  2.28749D-02
#  Bad direction in the line search;
#    refresh the lbfgs memory and restart the iteration.
#
#  Warning:  more than 10 function and gradient
#    evaluations in the last line search.  Termination
#    may possibly be caused by a bad search direction.
# /opt/conda/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:836: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# /opt/conda/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:836: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(
# /opt/conda/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /opt/conda/lib/python3.10/site-packages/statsmodels/tsa/statespace/sarimax.py:997: UserWarning: Non-stationary starting seasonal autoregressive Using zeros as starting parameters.
#   warn('Non-stationary starting seasonal autoregressive'
#  This problem is unconstrained.
# /opt/conda/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:836: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# /opt/conda/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:836: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(
# /opt/conda/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
#  This problem is unconstrained.
# /opt/conda/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:836: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# /opt/conda/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:836: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(
# /opt/conda/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
#  This problem is unconstrained.
# At iterate   10    f=  1.46357D-01    |proj g|=  1.72174D-01
#
# At iterate   15    f=  1.28409D-01    |proj g|=  1.20896D-01
#
# At iterate   20    f=  1.05261D-01    |proj g|=  5.14076D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3     23     42      1     0     0   2.381D-04   1.053D-01
#   F =  0.10525998988809006
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -8.82561D-02    |proj g|=  2.17956D-01
#
# At iterate    5    f= -1.70298D-01    |proj g|=  3.32956D-01
#
# At iterate   10    f= -1.73018D-01    |proj g|=  1.74658D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3     13     33      1     0     0   3.673D-04  -1.730D-01
#   F = -0.17301769226807795
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -9.02893D-01    |proj g|=  8.78755D+00
#
# At iterate    5    f= -1.08250D+00    |proj g|=  3.59632D-01
#
# At iterate   10    f= -1.10345D+00    |proj g|=  1.75187D+00
#
# At iterate   15    f= -1.12240D+00    |proj g|=  3.04362D+00
# /opt/conda/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:836: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# /opt/conda/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:836: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(
# /opt/conda/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /opt/conda/lib/python3.10/site-packages/statsmodels/tsa/statespace/sarimax.py:997: UserWarning: Non-stationary starting seasonal autoregressive Using zeros as starting parameters.
#   warn('Non-stationary starting seasonal autoregressive'
#  This problem is unconstrained.
# /opt/conda/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:836: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# /opt/conda/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:836: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(
# /opt/conda/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
#  This problem is unconstrained.
#
#  Bad direction in the line search;
#    refresh the lbfgs memory and restart the iteration.
#
#  Bad direction in the line search;
#    refresh the lbfgs memory and restart the iteration.
#
#  Bad direction in the line search;
#    refresh the lbfgs memory and restart the iteration.
# /opt/conda/lib/python3.10/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
#
#  Line search cannot locate an adequate point after MAXLS
#   function and gradient evaluations.
#   Previous x, f and g restored.
#  Possible causes: 1 error in function or gradient evaluation;
#                   2 rounding error dominate computation.
# /opt/conda/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:836: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# /opt/conda/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:836: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(
# /opt/conda/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
#  This problem is unconstrained.
# /opt/conda/lib/python3.10/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
#
#  Line search cannot locate an adequate point after MAXLS
#   function and gradient evaluations.
#   Previous x, f and g restored.
#  Possible causes: 1 error in function or gradient evaluation;
#                   2 rounding error dominate computation.
# /opt/conda/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:836: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# /opt/conda/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:836: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(
# /opt/conda/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /opt/conda/lib/python3.10/site-packages/statsmodels/tsa/statespace/sarimax.py:997: UserWarning: Non-stationary starting seasonal autoregressive Using zeros as starting parameters.
#   warn('Non-stationary starting seasonal autoregressive'
#  This problem is unconstrained.
# At iterate   20    f= -1.15144D+00    |proj g|=  2.81304D-02
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3     21    124      4     0     0   2.813D-02  -1.151D+00
#   F =  -1.1514390339256406
#
# ABNORMAL_TERMINATION_IN_LNSRCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -6.46732D+00    |proj g|=  8.10841D+04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3      1     21      1     0     0   8.108D+04  -6.467D+00
#   F =  -6.4673237511833221
#
# ABNORMAL_TERMINATION_IN_LNSRCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -5.86605D-01    |proj g|=  7.06338D-01
#
# At iterate    5    f= -5.91900D-01    |proj g|=  4.29914D-01
#
# At iterate   10    f= -6.37271D-01    |proj g|=  3.71205D+00
#
# At iterate   15    f= -7.22175D-01    |proj g|=  2.70928D+00
#   ys=-8.775E-05  -gs= 4.917E-06 BFGS update SKIPPED
#
# At iterate   20    f= -7.23728D-01    |proj g|=  3.33734D-02
#
# At iterate   25    f= -7.23728D-01    |proj g|=  9.37592D-03
#   ys=-4.605E-13  -gs= 3.848E-13 BFGS update SKIPPED
#   ys=-3.798E-14  -gs= 2.440E-13 BFGS update SKIPPED
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3     27    128      2     3     0   1.041D-02  -7.237D-01
#   F = -0.72372837130735801
#
# ABNORMAL_TERMINATION_IN_LNSRCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -5.61671D-01    |proj g|=  2.93846D+01
#
# At iterate    5    f= -7.85976D-01    |proj g|=  6.55423D-02
#
# At iterate   10    f= -7.87521D-01    |proj g|=  8.57452D-01
#
# At iterate   15    f= -8.02011D-01    |proj g|=  1.67749D-02
#
# At iterate   20    f= -8.02012D-01    |proj g|=  1.56365D-02
#  Bad direction in the line search;
#    refresh the lbfgs memory and restart the iteration.
# /opt/conda/lib/python3.10/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
#
#  Line search cannot locate an adequate point after MAXLS
#   function and gradient evaluations.
#   Previous x, f and g restored.
#  Possible causes: 1 error in function or gradient evaluation;
#                   2 rounding error dominate computation.
# /opt/conda/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:836: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# /opt/conda/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:836: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(
# /opt/conda/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
#  This problem is unconstrained.
# At iterate   25    f= -8.02038D-01    |proj g|=  6.30421D-02
#
# At iterate   30    f= -8.02057D-01    |proj g|=  2.15222D-02
#
# At iterate   35    f= -8.02062D-01    |proj g|=  5.29681D-02
#
# At iterate   40    f= -8.02069D-01    |proj g|=  1.19483D-02
#
# At iterate   45    f= -8.02079D-01    |proj g|=  1.79072D-02
#
# At iterate   50    f= -8.02085D-01    |proj g|=  3.86042D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3     50    128      3     0     0   3.860D-03  -8.021D-01
#   F = -0.80208506819233549
#
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  4.61303D-01    |proj g|=  9.89645D-02
#
# At iterate    5    f=  4.10126D-01    |proj g|=  2.50301D-02
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3      8     12      1     0     0   3.271D-06   4.101D-01
#   F =  0.41006961100401190
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
#  Bad direction in the line search;
#    refresh the lbfgs memory and restart the iteration.
#
#  Bad direction in the line search;
#    refresh the lbfgs memory and restart the iteration.
# /opt/conda/lib/python3.10/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /opt/conda/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:836: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# /opt/conda/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:836: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(
# /opt/conda/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# ...
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -8.92630D-01    |proj g|=  4.34489D+00
#
# At iterate    5    f= -9.19266D-01    |proj g|=  3.69010D-01
#
# At iterate   10    f= -9.28583D-01    |proj g|=  1.46198D-01
#
# At iterate   15    f= -9.30505D-01    |proj g|=  3.16543D-02
#
# At iterate   20    f= -9.30530D-01    |proj g|=  3.40443D-02
# /opt/conda/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:836: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# /opt/conda/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:836: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(
# /opt/conda/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
#  This problem is unconstrained.
# /opt/conda/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:836: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# /opt/conda/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:836: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(
# /opt/conda/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
#  This problem is unconstrained.
# At iterate   25    f= -9.30534D-01    |proj g|=  3.69999D-02
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3     28     56      1     0     0   2.117D-02  -9.305D-01
#   F = -0.93053387994152315
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -8.92630D-01    |proj g|=  4.34489D+00
#
# At iterate    5    f= -9.19266D-01    |proj g|=  3.69010D-01
#
# At iterate   10    f= -9.28583D-01    |proj g|=  1.46198D-01
#
# At iterate   15    f= -9.30505D-01    |proj g|=  3.16543D-02
#
# At iterate   20    f= -9.30530D-01    |proj g|=  3.40443D-02
#
# At iterate   25    f= -9.30534D-01    |proj g|=  3.69999D-02
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3     28     56      1     0     0   2.117D-02  -9.305D-01
#   F = -0.93053387994152315
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -1.21145D+00    |proj g|=  6.32185D-01
#
# At iterate    5    f= -1.21161D+00    |proj g|=  1.42311D-01
#
# At iterate   10    f= -1.21402D+00    |proj g|=  3.20904D-01
#
# At iterate   15    f= -1.21405D+00    |proj g|=  4.43962D-03
# /opt/conda/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:836: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# /opt/conda/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:836: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(
# /opt/conda/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
#  This problem is unconstrained.
# /opt/conda/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:836: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# /opt/conda/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:836: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(
# /opt/conda/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
#  This problem is unconstrained.
# At iterate   20    f= -1.21407D+00    |proj g|=  1.50989D-02
#
# At iterate   25    f= -1.21407D+00    |proj g|=  1.46711D-01
#   ys=-1.673E-06  -gs= 4.958E-07 BFGS update SKIPPED
#
# At iterate   30    f= -1.21408D+00    |proj g|=  1.18004D-02
#   ys=-2.484E-09  -gs= 1.512E-08 BFGS update SKIPPED
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3     32    120      2     2     0   7.909D-03  -1.214D+00
#   F =  -1.2140805749906491
#
# ABNORMAL_TERMINATION_IN_LNSRCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -1.21127D+00    |proj g|=  6.23486D-01
#
# At iterate    5    f= -1.21142D+00    |proj g|=  3.70026D-01
#
# At iterate   10    f= -1.21384D+00    |proj g|=  3.08318D-02
#  Bad direction in the line search;
#    refresh the lbfgs memory and restart the iteration.
# /opt/conda/lib/python3.10/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
#
#  Line search cannot locate an adequate point after MAXLS
#   function and gradient evaluations.
#   Previous x, f and g restored.
#  Possible causes: 1 error in function or gradient evaluation;
#                   2 rounding error dominate computation.
# /opt/conda/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:836: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# /opt/conda/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:836: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(
# /opt/conda/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
#  This problem is unconstrained.
#
#  Bad direction in the line search;
#    refresh the lbfgs memory and restart the iteration.
# At iterate   15    f= -1.21385D+00    |proj g|=  3.39641D-03
#   ys=-2.355E-10  -gs= 2.400E-10 BFGS update SKIPPED
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3     19    128      3     1     0   6.944D-03  -1.214D+00
#   F =  -1.2138451731471049
#
# ABNORMAL_TERMINATION_IN_LNSRCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -1.21145D+00    |proj g|=  6.32185D-01
#
# At iterate    5    f= -1.21161D+00    |proj g|=  1.42311D-01
#  Bad direction in the line search;
#    refresh the lbfgs memory and restart the iteration.
# /opt/conda/lib/python3.10/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
#
#  Line search cannot locate an adequate point after MAXLS
#   function and gradient evaluations.
#   Previous x, f and g restored.
#  Possible causes: 1 error in function or gradient evaluation;
#                   2 rounding error dominate computation.
# /opt/conda/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:836: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# /opt/conda/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:836: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(
# /opt/conda/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
#  This problem is unconstrained.
# At iterate   10    f= -1.21402D+00    |proj g|=  3.20904D-01
#
# At iterate   15    f= -1.21405D+00    |proj g|=  4.43962D-03
#
# At iterate   20    f= -1.21407D+00    |proj g|=  1.50989D-02
#
# At iterate   25    f= -1.21407D+00    |proj g|=  1.46711D-01
#   ys=-1.673E-06  -gs= 4.958E-07 BFGS update SKIPPED
#
# At iterate   30    f= -1.21408D+00    |proj g|=  1.18004D-02
#   ys=-2.484E-09  -gs= 1.512E-08 BFGS update SKIPPED
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3     32    120      2     2     0   7.909D-03  -1.214D+00
#   F =  -1.2140805749906491
#
# ABNORMAL_TERMINATION_IN_LNSRCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -3.11438D-01    |proj g|=  2.44869D-01
#
# At iterate    5    f= -3.11979D-01    |proj g|=  1.75425D-02
#
# At iterate   10    f= -3.12082D-01    |proj g|=  1.85367D-03
#
# At iterate   15    f= -3.12090D-01    |proj g|=  4.23000D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3     17     34      1     0     0   1.584D-04  -3.121D-01
#   F = -0.31209065152139953
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -5.06006D-01    |proj g|=  3.99603D-01
#
# At iterate    5    f= -5.07028D-01    |proj g|=  1.84655D-01
#
# At iterate   10    f= -5.08766D-01    |proj g|=  3.05508D-03
#
# At iterate   15    f= -5.08767D-01    |proj g|=  9.04549D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3     19     29      1     0     0   4.643D-04  -5.088D-01
#   F = -0.50876778863185934
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#  Bad direction in the line search;
#    refresh the lbfgs memory and restart the iteration.
# /opt/conda/lib/python3.10/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
#
#  Line search cannot locate an adequate point after MAXLS
#   function and gradient evaluations.
#   Previous x, f and g restored.
#  Possible causes: 1 error in function or gradient evaluation;
#                   2 rounding error dominate computation.
# /opt/conda/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:836: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# /opt/conda/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:836: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(
# /opt/conda/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
#  This problem is unconstrained.
#
#  Warning:  more than 10 function and gradient
#    evaluations in the last line search.  Termination
#    may possibly be caused by a bad search direction.
# /opt/conda/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:836: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# /opt/conda/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:836: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(
# /opt/conda/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
#  This problem is unconstrained.
# /opt/conda/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:836: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# /opt/conda/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:836: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(

# %%
sample_submission.head(5)
# Out:
#      Country Name  2016 [YR2016]  2017 [YR2017]  2018 [YR2018]  2019 [YR2019]  \
# 0     Afghanistan       0.287907       0.320518       0.323758       0.339657
# 1         Albania       1.866266       1.935703       1.777523       1.862128
# 2         Algeria       3.957503       4.069786       4.266931       4.304901
# 3  American Samoa       0.000000       0.000000       0.000000       0.000000
# 4         Andorra       6.568557       6.451696       6.110751       6.142191
#
#    2020 [YR2020]  2030 [YR2030]
# 0       0.389872       0.556750
# 1       1.975866       2.194618
# 2       4.420214       5.550121
# 3       0.000000       0.000000
# 4       6.251308       5.385008

# %%
sample_submission.to_csv('submission.csv', index=False)
